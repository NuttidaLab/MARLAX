# %%
import pandas as pd
import numpy as np
from joblib import Parallel, delayed
from contextlib import contextmanager
import joblib
from tqdm import tqdm
import os
import pathlib
tqdm.pandas()

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from matplotlib.animation import PillowWriter
from matplotlib.patches import Ellipse, Circle
import seaborn as sns

pd.set_option('display.max_rows', 500)

from IPython.display import HTML

# %%
# Predefined lookup and type dictionary
grid = (11,11)
reward_place_to_coord = {
    "u": ((grid[0] // 2, grid[1] - 1),),
    "r": ((grid[0] - 1, grid[1] // 2),),
    "d": ((grid[0] // 2, 0),),
    "l": ((0, grid[1] // 2),),
    "ur": ((grid[0] // 2, grid[1] - 1), (grid[0] - 1, grid[1] // 2)),
    "rd": ((grid[0] - 1, grid[1] // 2), (grid[0] // 2, 0)),
    "dl": ((grid[0] // 2, 0), (0, grid[1] // 2)),
    "ul": ((0, grid[1] // 2), (grid[0] // 2, grid[1] - 1)),
    "ud": ((grid[0] // 2, grid[1] - 1), (grid[0] // 2, 0)),
    "rl": ((grid[0] - 1, grid[1] // 2), (0, grid[1] // 2)),
    # Note: Replace this with the updated one
}        # Mapping from reward identifiers to board coordinates.

reverse_reward_place_to_coord = {
    (0, grid[1] // 2): "l",
    (grid[0] - 1, grid[1] // 2): "r",
    (grid[0] // 2, 0): "d",
    (grid[0] // 2, grid[1] - 1): "u",
}

stats_dtype = {
    "trial_id": "int32",
    "activated": "bool",
    "collected": "bool",
    "reward_loc": "object",
    "activated_by": "object",
    "activated_frame": "object",
    "first_close_to_zone": "object",
    "first_close_to_zone_frame": "object",
    "first_to_zone": "object",
    "first_to_zone_frame": "object",
    "reward_counter": "float64"
}

# Our custom context manager to hook joblib with tqdm
@contextmanager
def tqdm_joblib(tqdm_object):
    """Context manager to patch joblib to report into tqdm progress bar."""
    class TqdmBatchCompletionCallback(joblib.parallel.BatchCompletionCallBack):
        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
        def __call__(self, *args, **kwargs):
            tqdm_object.update(n=self.batch_size)
            return super().__call__(*args, **kwargs)
    old_callback = joblib.parallel.BatchCompletionCallBack
    joblib.parallel.BatchCompletionCallBack = TqdmBatchCompletionCallback
    try:
        yield tqdm_object
    finally:
        joblib.parallel.BatchCompletionCallBack = old_callback
        tqdm_object.close()

# %%
# Function to compute trial stats in parallel
def compute_trial_stats(trial_df):
    """
    Given a DataFrame corresponding to a single trial,
    compute aggregated trial-level statistics.
    """
    trial_length = len(trial_df)
    
    reward_loc = trial_df.iloc[-1]['reward_loc']
    reward_counter = trial_df['r1'].sum()
    collected = trial_df.iloc[-1]['collected']
    trial_start = int(trial_df.iloc[0]['frame_idx'])
    activated = False
    
    wz_cancel = False
    
    if (collected == False) & (trial_df.iloc[-1]["steps_without_reward"] < 51):
        wz_cancel = True
    
    collected_zone = None
    # Find the zone where the reward was collected
    if collected:
        row = trial_df.iloc[-1]
        collected_zone = reverse_reward_place_to_coord.get((row['a1x'], row['a1y']), None)
    
    # Leader #1: Activated info (first frame where activated == True)
    activated_by = None
    activated_frame = None
    act_rows = trial_df[trial_df['activated']]
    if not act_rows.empty:
        activated = True
        row_act = act_rows.iloc[0]
        activated_frame = int(row_act["frame_idx"]) - trial_start  # Adjust for trial start
        # Check conditions for the activated leader
        if (row_act['a1x'] == row_act['a1y']) and (row_act['a2x'] == row_act['a2y']) and (row_act['a1x'] == 5):
            activated_by = "tie"
        elif (row_act['a1x'] == row_act['a1y']) and (row_act['a1x'] == 5):
            activated_by = "a1"
        elif (row_act['a2x'] == row_act['a2y']) and (row_act['a2x'] == 5):
            activated_by = "a2"
    
    # Leader #2: Who gets within 2 Euclidean distance of any reward zone coordinate first?
    first_close_to_zone = None
    first_close_to_zone_frame = None
    # Only evaluate if reward_loc is set (note: it might be a string 'None' or an actual None)
    if reward_loc not in ['None', None]:
        # Convert reward_loc string into tuple using ast.literal_eval
        reward_coords = reward_place_to_coord.get(reward_loc, ())
        # Iterate over frames in order
        for i, row in trial_df.iterrows():
            for coords in reward_coords:
                a1_dist = np.linalg.norm(np.array([row['a1x'], row['a1y']]) - np.array(coords))
                a2_dist = np.linalg.norm(np.array([row['a2x'], row['a2y']]) - np.array(coords))
                closeness_thresh = 2
                if a1_dist <= closeness_thresh and a2_dist <= closeness_thresh:
                    first_close_to_zone = "tie"
                    first_close_to_zone_frame = i
                    break
                elif a1_dist <= closeness_thresh:
                    first_close_to_zone = "a1"
                    first_close_to_zone_frame = i
                    break
                elif a2_dist <= closeness_thresh:
                    first_close_to_zone = "a2"
                    first_close_to_zone_frame = i
                    break
            if first_close_to_zone is not None:
                break

    # Leader #3: Who reaches the reward zone exactly first?
    first_to_zone = None
    first_to_zone_frame = None
    if reward_loc not in ['None', None]:
        reward_coords = reward_place_to_coord.get(reward_loc, ())
        for i, row in trial_df.iterrows():
            for coords in reward_coords:
                if (row['a1x'], row['a1y']) == (row['a2x'], row['a2y']) == coords:
                    first_to_zone = "tie"
                    first_to_zone_frame = i
                    break
                elif (row['a1x'], row['a1y']) == coords:
                    first_to_zone = "a1"
                    first_to_zone_frame = i
                    break
                elif (row['a2x'], row['a2y']) == coords:
                    first_to_zone = "a2"
                    first_to_zone_frame = i
                    break
            if first_to_zone is not None:
                break

    return pd.Series({
        "trial_length": trial_length,
        "activated": activated,
        "collected": collected,
        "wz_cancel": wz_cancel,
        "collected_zone": collected_zone,
        "reward_loc": reward_loc,
        "activated_by": activated_by,
        "activated_frame": activated_frame,
        "first_close_to_zone": first_close_to_zone,
        "first_close_to_zone_frame": first_close_to_zone_frame,
        "first_to_zone": first_to_zone,
        "first_to_zone_frame": first_to_zone_frame,
        "reward_counter": reward_counter
    })

# %%
# Folded statistics computation
def compute_folded_stats(df, trail_function, n_folds=20):
    gids = df.groupby("trial_id", group_keys=False).indices
    chunk_idxs = np.array_split(list(gids.keys()), n_folds)
    start_ends = [(gids[chunk[0]][0], gids[chunk[-1]][-1]) for chunk in chunk_idxs]

    def process_chunk(start, end):
        sdf = df.loc[start:end]
        return (
            sdf.groupby("trial_id", group_keys=False)
               .apply(trail_function, include_groups=False)
               .reset_index()
        )

    with tqdm_joblib(tqdm(total=len(start_ends), desc="Processing chunks")) as progress_bar:
        stats = pd.concat(
            Parallel(n_jobs=n_folds, backend="loky", prefer="processes")(
                delayed(process_chunk)(start, end) for start, end in start_ends
            )
        )
    return stats.reset_index(drop=True)

# %%
# get every folder in store_w
base= "../store_bk"
trains = sorted(os.listdir(base))

for train in trains[:]:
    store = f"{base}/{train}/logs/"
    export = f"{base}/{train}/trial_stats/"
    
    # Create the export folder if it doesn't exist
    # Delete the existing export folder if it exists
    if os.path.exists(export):
        import shutil
        shutil.rmtree(export)
    # Create the export directory
    pathlib.Path(export).mkdir(parents=True, exist_ok=True)
    
    files = os.listdir(store)
    for file in files:
        tdf = pd.read_parquet(f'{store}{file}')
        tdf["trial_id"] = tdf.terminated.cumsum().shift(fill_value=0)
        trial_stats = compute_folded_stats(tdf, compute_trial_stats, 50)
        trial_stats.to_parquet(f'{export}{file}')
# Out:
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 23.19it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.81it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.31it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.97it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.79it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.54it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.86it/s]
# Processing chunks: 100%|██████████| 50/50 [00:13<00:00,  3.80it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.57it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.63it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.17it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.94it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.27it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.59it/s]
# Processing chunks: 100%|██████████| 50/50 [00:03<00:00, 16.38it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.70it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.45it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.97it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.80it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.75it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.99it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.27it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.34it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.86it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.94it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.19it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.20it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.30it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.98it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.61it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.49it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.44it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.97it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.83it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.51it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.55it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 44.46it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.88it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.87it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.98it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.23it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.71it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 44.37it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.89it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.98it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.88it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.32it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.96it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.80it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.92it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.13it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.99it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.43it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.10it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.15it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.71it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.18it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.90it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.72it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.41it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.59it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.65it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 45.19it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.15it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.98it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.49it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.42it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.11it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.24it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.74it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.22it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.93it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.60it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.28it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.71it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.32it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.91it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.27it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.51it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.24it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.83it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.29it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.54it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.34it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.21it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.63it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.09it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.27it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.50it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.38it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.43it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.55it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.19it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.88it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.34it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 45.70it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.40it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.09it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.37it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.81it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.94it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 44.11it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.35it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.79it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.46it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.80it/s]
# Processing chunks: 100%|██████████| 50/50 [00:03<00:00, 16.58it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 38.42it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.26it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.88it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.18it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.18it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.24it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.93it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.97it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.35it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.84it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.25it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.31it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.31it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.47it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 44.18it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.26it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.93it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 38.38it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.14it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.96it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.94it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.17it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.90it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.64it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.77it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.38it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.56it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.98it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.93it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.32it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.28it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.16it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.32it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.41it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.35it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.28it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.11it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.64it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.77it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.70it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.58it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.69it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.55it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.14it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.20it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.96it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 45.42it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.98it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.99it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.75it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.62it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.20it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.74it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.17it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 44.64it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.26it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.34it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.91it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.86it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.63it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.74it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.09it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.64it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.99it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.64it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.89it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.53it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.39it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.16it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.18it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.12it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.70it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.88it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.19it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.65it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.56it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.69it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.50it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 44.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.88it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.94it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.17it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.69it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.99it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.93it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.61it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.74it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.52it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.57it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.52it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.79it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.56it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.41it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.85it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.25it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.67it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.28it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.43it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 21.45it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.41it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.99it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.18it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.26it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.29it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.57it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.95it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.17it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.17it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.10it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.49it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.13it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.95it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.64it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.49it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.11it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.86it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.61it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 45.39it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.47it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.36it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.00it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.37it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.80it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.84it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 44.54it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.72it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.96it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.87it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.63it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.90it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.01it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.37it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.44it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.42it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 45.10it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.91it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.31it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.08it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.52it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.92it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.21it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.35it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.23it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.45it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.05it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.91it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.77it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.42it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.38it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.51it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.03it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.47it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.92it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.85it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 43.47it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.26it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.26it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.77it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.58it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.43it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.19it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.24it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.09it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 39.14it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.58it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 16.89it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.98it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 44.54it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.89it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.59it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.53it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.78it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.12it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.62it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.25it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.55it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.02it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 41.77it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.25it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 17.51it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.04it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.37it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.26it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.60it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  3.98it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 42.89it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 19.41it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.47it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.06it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 40.84it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.64it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 16.90it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]
# Processing chunks: 100%|██████████| 50/50 [00:01<00:00, 38.63it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 20.61it/s]
# Processing chunks: 100%|██████████| 50/50 [00:02<00:00, 18.61it/s]
# Processing chunks: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]

# %%
# # get every folder in store_w
# base= "../store_bk"
# trains = sorted(os.listdir(base))

# for train in trains[:]:
#     store = f"{base}/{train}/logs/"
#     export = f"{base}/{train}/trial_stats/"
    
#     # Create the export folder if it doesn't exist
#     pathlib.Path(export).mkdir(parents=True, exist_ok=True)
    
#     file = 'testing_1.parquet'
#     tdf = pd.read_parquet(f'{store}{file}')
#     tdf["trial_id"] = tdf.terminated.cumsum().shift(fill_value=0)
#     trial_stats = compute_folded_stats(tdf, compute_trial_stats, 50)
#     trial_stats.to_parquet(f'{export}{file}')
